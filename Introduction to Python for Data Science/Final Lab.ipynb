# %% [markdown]
# ### Section 1: Importing and Summarizing Data

# %%
# Import pandas 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# Use pandas to read in recent_grads_url
recent_grads = pd.read_csv("recent-grads.csv")

# Print the shape
recent_grads.shape
# Out:
# (173, 21)

# %%
# Print .dtypes
recent_grads.dtypes
# Out:
# Rank                      int64
# Major_code                int64
# Major                    object
# Total                   float64
# Men                     float64
# Women                   float64
# Major_category           object
# ShareWomen              float64
# Sample_size               int64
# Employed                  int64
# Full_time                 int64
# Part_time                 int64
# Full_time_year_round      int64
# Unemployed                int64
# Unemployment_rate       float64
# Median                    int64
# P25th                     int64
# P75th                     int64
# College_jobs              int64
# Non_college_jobs          int64
# Low_wage_jobs             int64
# dtype: object

# %%
# Output summary statistics
recent_grads.describe()
# Out:
#              Rank   Major_code          Total            Men          Women  \
# count  173.000000   173.000000     172.000000     172.000000     172.000000
# mean    87.000000  3879.815029   39370.081395   16723.406977   22646.674419
# std     50.084928  1687.753140   63483.491009   28122.433474   41057.330740
# min      1.000000  1100.000000     124.000000     119.000000       0.000000
# 25%     44.000000  2403.000000    4549.750000    2177.500000    1778.250000
# 50%     87.000000  3608.000000   15104.000000    5434.000000    8386.500000
# 75%    130.000000  5503.000000   38909.750000   14631.000000   22553.750000
# max    173.000000  6403.000000  393735.000000  173809.000000  307087.000000
#
#        ShareWomen  Sample_size       Employed      Full_time      Part_time  \
# count  172.000000   173.000000     173.000000     173.000000     173.000000
# mean     0.522223   356.080925   31192.763006   26029.306358    8832.398844
# std      0.231205   618.361022   50675.002241   42869.655092   14648.179473
# min      0.000000     2.000000       0.000000     111.000000       0.000000
# 25%      0.336026    39.000000    3608.000000    3154.000000    1030.000000
# 50%      0.534024   130.000000   11797.000000   10048.000000    3299.000000
# 75%      0.703299   338.000000   31433.000000   25147.000000    9948.000000
# max      0.968954  4212.000000  307933.000000  251540.000000  115172.000000
#
#        Full_time_year_round    Unemployed  Unemployment_rate         Median  \
# count            173.000000    173.000000         173.000000     173.000000
# mean           19694.427746   2416.329480           0.068191   40151.445087
# std            33160.941514   4112.803148           0.030331   11470.181802
# min              111.000000      0.000000           0.000000   22000.000000
# 25%             2453.000000    304.000000           0.050306   33000.000000
# 50%             7413.000000    893.000000           0.067961   36000.000000
# 75%            16891.000000   2393.000000           0.087557   45000.000000
# max           199897.000000  28169.000000           0.177226  110000.000000
#
#               P25th          P75th   College_jobs  Non_college_jobs  \
# count    173.000000     173.000000     173.000000        173.000000
# mean   29501.445087   51494.219653   12322.635838      13284.497110
# std     9166.005235   14906.279740   21299.868863      23789.655363
# min    18500.000000   22000.000000       0.000000          0.000000
# 25%    24000.000000   42000.000000    1675.000000       1591.000000
# 50%    27000.000000   47000.000000    4390.000000       4595.000000
# 75%    33000.000000   60000.000000   14444.000000      11783.000000
# max    95000.000000  125000.000000  151643.000000     148395.000000
#
#        Low_wage_jobs
# count     173.000000
# mean     3859.017341
# std      6944.998579
# min         0.000000
# 25%       340.000000
# 50%      1231.000000
# 75%      3466.000000
# max     48207.000000

# %%
# Exclude data of type object
recent_grads.describe(exclude=['object'])
# Out:
#              Rank   Major_code          Total            Men          Women  \
# count  173.000000   173.000000     172.000000     172.000000     172.000000
# mean    87.000000  3879.815029   39370.081395   16723.406977   22646.674419
# std     50.084928  1687.753140   63483.491009   28122.433474   41057.330740
# min      1.000000  1100.000000     124.000000     119.000000       0.000000
# 25%     44.000000  2403.000000    4549.750000    2177.500000    1778.250000
# 50%     87.000000  3608.000000   15104.000000    5434.000000    8386.500000
# 75%    130.000000  5503.000000   38909.750000   14631.000000   22553.750000
# max    173.000000  6403.000000  393735.000000  173809.000000  307087.000000
#
#        ShareWomen  Sample_size       Employed      Full_time      Part_time  \
# count  172.000000   173.000000     173.000000     173.000000     173.000000
# mean     0.522223   356.080925   31192.763006   26029.306358    8832.398844
# std      0.231205   618.361022   50675.002241   42869.655092   14648.179473
# min      0.000000     2.000000       0.000000     111.000000       0.000000
# 25%      0.336026    39.000000    3608.000000    3154.000000    1030.000000
# 50%      0.534024   130.000000   11797.000000   10048.000000    3299.000000
# 75%      0.703299   338.000000   31433.000000   25147.000000    9948.000000
# max      0.968954  4212.000000  307933.000000  251540.000000  115172.000000
#
#        Full_time_year_round    Unemployed  Unemployment_rate         Median  \
# count            173.000000    173.000000         173.000000     173.000000
# mean           19694.427746   2416.329480           0.068191   40151.445087
# std            33160.941514   4112.803148           0.030331   11470.181802
# min              111.000000      0.000000           0.000000   22000.000000
# 25%             2453.000000    304.000000           0.050306   33000.000000
# 50%             7413.000000    893.000000           0.067961   36000.000000
# 75%            16891.000000   2393.000000           0.087557   45000.000000
# max           199897.000000  28169.000000           0.177226  110000.000000
#
#               P25th          P75th   College_jobs  Non_college_jobs  \
# count    173.000000     173.000000     173.000000        173.000000
# mean   29501.445087   51494.219653   12322.635838      13284.497110
# std     9166.005235   14906.279740   21299.868863      23789.655363
# min    18500.000000   22000.000000       0.000000          0.000000
# 25%    24000.000000   42000.000000    1675.000000       1591.000000
# 50%    27000.000000   47000.000000    4390.000000       4595.000000
# 75%    33000.000000   60000.000000   14444.000000      11783.000000
# max    95000.000000  125000.000000  151643.000000     148395.000000
#
#        Low_wage_jobs
# count     173.000000
# mean     3859.017341
# std      6944.998579
# min         0.000000
# 25%       340.000000
# 50%      1231.000000
# 75%      3466.000000
# max     48207.000000

# %%
recent_grads.columns
# Out:
# Index(['Rank', 'Major_code', 'Major', 'Total', 'Men', 'Women',
#        'Major_category', 'ShareWomen', 'Sample_size', 'Employed', 'Full_time',
#        'Part_time', 'Full_time_year_round', 'Unemployed', 'Unemployment_rate',
#        'Median', 'P25th', 'P75th', 'College_jobs', 'Non_college_jobs',
#        'Low_wage_jobs'],
#       dtype='object')

# %%
# Names of the columns we're searching for missing values 
columns = ['Median', 'P25th', 'P75th']

# %%
# Take a look at the dtypes
recent_grads[columns].dtypes
# Out:
# Median    int64
# P25th     int64
# P75th     int64
# dtype: object

# %%
# Find how missing values are represente
recent_grads["Median"].unique()
# Out:
# array([110000,  75000,  73000,  70000,  65000,  62000,  60000,  58000,
#         57100,  57000,  56000,  54000,  53000,  52000,  51000,  50000,
#         48000,  47000,  46000,  45000,  44700,  44000,  42000,  41300,
#         41000,  40100,  40000,  39000,  38400,  38000,  37500,  37400,
#         37000,  36400,  36200,  36000,  35600,  35000,  34000,  33500,
#         33400,  33000,  32500,  32400,  32200,  32100,  32000,  31500,
#         31000,  30500,  30000,  29000,  28000,  27500,  27000,  26000,
#         25000,  23400,  22000], dtype=int64)

# %%
# Replace missing values with NaN
for column in columns:
    recent_grads.loc[recent_grads[column] == 'UN', column] = np.nan

# %%
# Select sharewomen column
sw_col = recent_grads.ShareWomen

# %%
# Output first five rows
sw_col[0:5]
# Out:
# 0    0.120564
# 1    0.101852
# 2    0.153037
# 3    0.107313
# 4    0.341631
# Name: ShareWomen, dtype: float64

# %%
# Use max to output maximum values
max_sw = np.max(sw_col)

# Print column max
max_sw
# Out:
# 0.968953683

# %%
recent_grads[sw_col == max_sw]
# Out:
#      Rank  Major_code                      Major    Total     Men    Women  \
# 164   165        2307  EARLY CHILDHOOD EDUCATION  37589.0  1167.0  36422.0
#
#     Major_category  ShareWomen  Sample_size  Employed  ...  Part_time  \
# 164      Education    0.968954          342     32551  ...       7001
#
#      Full_time_year_round  Unemployed  Unemployment_rate   Median    P25th  \
# 164                 20748        1360           0.040105  28000.0  21000.0
#
#        P75th  College_jobs  Non_college_jobs  Low_wage_jobs
# 164  35000.0         23515              7705           2868
#
# [1 rows x 21 columns]

# %%
recent_grads[["Unemployed","Low_wage_jobs"]]
# Out:
#      Unemployed  Low_wage_jobs
# 0            37            193
# 1            85             50
# 2            16              0
# 3            40              0
# 4          1672            972
# ..          ...            ...
# 168         304            743
# 169         148             82
# 170         368            622
# 171         214            308
# 172          87            192
#
# [173 rows x 2 columns]

# %%
recent_grads_np = np.array(recent_grads[["Unemployed","Low_wage_jobs"]])

# %%
type(recent_grads_np)
# Out:
# numpy.ndarray

# %%
x = np.array(recent_grads["Unemployed"])

# %%
y = np.array(recent_grads["Low_wage_jobs"])

# %%
# Calculate correlation matrix
np.corrcoef(x,y)
# Out:
# array([[1.        , 0.95538815],
#        [0.95538815, 1.        ]])

# %% [markdown]
# ### Section 2: Manipulating Data

# %%
recent_grads.head()
# Out:
#    Rank  Major_code                                      Major    Total  \
# 0     1        2419                      PETROLEUM ENGINEERING   2339.0
# 1     2        2416             MINING AND MINERAL ENGINEERING    756.0
# 2     3        2415                  METALLURGICAL ENGINEERING    856.0
# 3     4        2417  NAVAL ARCHITECTURE AND MARINE ENGINEERING   1258.0
# 4     5        2405                       CHEMICAL ENGINEERING  32260.0
#
#        Men    Women Major_category  ShareWomen  Sample_size  Employed  ...  \
# 0   2057.0    282.0    Engineering    0.120564           36      1976  ...
# 1    679.0     77.0    Engineering    0.101852            7       640  ...
# 2    725.0    131.0    Engineering    0.153037            3       648  ...
# 3   1123.0    135.0    Engineering    0.107313           16       758  ...
# 4  21239.0  11021.0    Engineering    0.341631          289     25694  ...
#
#    Part_time  Full_time_year_round  Unemployed  Unemployment_rate    Median  \
# 0        270                  1207          37           0.018381  110000.0
# 1        170                   388          85           0.117241   75000.0
# 2        133                   340          16           0.024096   73000.0
# 3        150                   692          40           0.050125   70000.0
# 4       5180                 16697        1672           0.061098   65000.0
#
#      P25th     P75th  College_jobs  Non_college_jobs  Low_wage_jobs
# 0  95000.0  125000.0          1534               364            193
# 1  55000.0   90000.0           350               257             50
# 2  50000.0  105000.0           456               176              0
# 3  43000.0   80000.0           529               102              0
# 4  50000.0   75000.0         18314              4440            972
#
# [5 rows x 21 columns]

# %%
# Add sharemen column
recent_grads['sharemen'] = recent_grads["Men"]/recent_grads["Total"]

# %%
recent_grads.head(3)
# Out:
#    Rank  Major_code                           Major   Total     Men  Women  \
# 0     1        2419           PETROLEUM ENGINEERING  2339.0  2057.0  282.0
# 1     2        2416  MINING AND MINERAL ENGINEERING   756.0   679.0   77.0
# 2     3        2415       METALLURGICAL ENGINEERING   856.0   725.0  131.0
#
#   Major_category  ShareWomen  Sample_size  Employed  ...  \
# 0    Engineering    0.120564           36      1976  ...
# 1    Engineering    0.101852            7       640  ...
# 2    Engineering    0.153037            3       648  ...
#
#    Full_time_year_round  Unemployed  Unemployment_rate    Median    P25th  \
# 0                  1207          37           0.018381  110000.0  95000.0
# 1                   388          85           0.117241   75000.0  55000.0
# 2                   340          16           0.024096   73000.0  50000.0
#
#       P75th  College_jobs  Non_college_jobs  Low_wage_jobs  sharemen
# 0  125000.0          1534               364            193  0.879436
# 1   90000.0           350               257             50  0.898148
# 2  105000.0           456               176              0  0.846963
#
# [3 rows x 22 columns]

# %%
# Find the maximum percentage value of men
max_men = np.max(recent_grads["sharemen"])

# %%
max_men
# Out:
# 1.0

# %%
recent_grads[recent_grads["sharemen"] == max_men]
# Out:
#     Rank  Major_code                  Major  Total    Men  Women  \
# 73    74        3801  MILITARY TECHNOLOGIES  124.0  124.0    0.0
#
#                          Major_category  ShareWomen  Sample_size  Employed  \
# 73  Industrial Arts & Consumer Services         0.0            4         0
#
#     ...  Full_time_year_round  Unemployed  Unemployment_rate   Median  \
# 73  ...                   111           0                0.0  40000.0
#
#       P25th    P75th  College_jobs  Non_college_jobs  Low_wage_jobs  sharemen
# 73  40000.0  40000.0             0                 0              0       1.0
#
# [1 rows x 22 columns]

# %%
# Add gender_diff column
recent_grads['gender_diff'] = recent_grads['ShareWomen']- recent_grads['sharemen']

# %%
recent_grads.head(3)
# Out:
#    Rank  Major_code                           Major   Total     Men  Women  \
# 0     1        2419           PETROLEUM ENGINEERING  2339.0  2057.0  282.0
# 1     2        2416  MINING AND MINERAL ENGINEERING   756.0   679.0   77.0
# 2     3        2415       METALLURGICAL ENGINEERING   856.0   725.0  131.0
#
#   Major_category  ShareWomen  Sample_size  Employed  ...  Unemployed  \
# 0    Engineering    0.120564           36      1976  ...          37
# 1    Engineering    0.101852            7       640  ...          85
# 2    Engineering    0.153037            3       648  ...          16
#
#    Unemployment_rate    Median    P25th     P75th  College_jobs  \
# 0           0.018381  110000.0  95000.0  125000.0          1534
# 1           0.117241   75000.0  55000.0   90000.0           350
# 2           0.024096   73000.0  50000.0  105000.0           456
#
#    Non_college_jobs  Low_wage_jobs  sharemen  gender_diff
# 0               364            193  0.879436    -0.758871
# 1               257             50  0.898148    -0.796296
# 2               176              0  0.846963    -0.693925
#
# [3 rows x 23 columns]

# %%
# Make all gender difference values positive
recent_grads['gender_diff'] = abs(recent_grads['gender_diff'])

# %%
recent_grads.head(3)
# Out:
#    Rank  Major_code                           Major   Total     Men  Women  \
# 0     1        2419           PETROLEUM ENGINEERING  2339.0  2057.0  282.0
# 1     2        2416  MINING AND MINERAL ENGINEERING   756.0   679.0   77.0
# 2     3        2415       METALLURGICAL ENGINEERING   856.0   725.0  131.0
#
#   Major_category  ShareWomen  Sample_size  Employed  ...  Unemployed  \
# 0    Engineering    0.120564           36      1976  ...          37
# 1    Engineering    0.101852            7       640  ...          85
# 2    Engineering    0.153037            3       648  ...          16
#
#    Unemployment_rate    Median    P25th     P75th  College_jobs  \
# 0           0.018381  110000.0  95000.0  125000.0          1534
# 1           0.117241   75000.0  55000.0   90000.0           350
# 2           0.024096   73000.0  50000.0  105000.0           456
#
#    Non_college_jobs  Low_wage_jobs  sharemen  gender_diff
# 0               364            193  0.879436     0.758871
# 1               257             50  0.898148     0.796296
# 2               176              0  0.846963     0.693925
#
# [3 rows x 23 columns]

# %%
recent_grads.nsmallest(5, 'gender_diff')
# Out:
#      Rank  Major_code                                          Major  \
# 139   140        4101  PHYSICAL FITNESS PARKS RECREATION AND LEISURE
# 102   103        5503                                    CRIMINOLOGY
# 74     75        5003                                      CHEMISTRY
# 146   147        6002                                          MUSIC
# 117   118        2311    SOCIAL SCIENCE OR HISTORY TEACHER EDUCATION
#
#         Total      Men    Women                       Major_category  \
# 139  125074.0  62181.0  62893.0  Industrial Arts & Consumer Services
# 102   19879.0  10031.0   9848.0                       Social Science
# 74    66530.0  32923.0  33607.0                    Physical Sciences
# 146   60633.0  29909.0  30724.0                                 Arts
# 117   20198.0   9950.0  10248.0                            Education
#
#      ShareWomen  Sample_size  Employed  ...  Unemployed  Unemployment_rate  \
# 139    0.502846         1014    103078  ...        5593           0.051467
# 102    0.495397          214     16181  ...        1743           0.097244
# 74     0.505141          353     48535  ...        2769           0.053972
# 146    0.506721          419     47662  ...        3918           0.075960
# 117    0.507377          157     17700  ...        1012           0.054083
#
#       Median    P25th    P75th  College_jobs  Non_college_jobs  Low_wage_jobs  \
# 139  32000.0  24000.0  43000.0         27581             63946          16838
# 102  35000.0  25000.0  45000.0          3373             10605           1895
# 74   39000.0  30000.0  49900.0         30382             14718           4288
# 146  31000.0  22300.0  42000.0         13752             28786           9286
# 117  34000.0  23050.0  42000.0         10928              5561           1806
#
#      sharemen  gender_diff
# 139  0.497154     0.005693
# 102  0.504603     0.009206
# 74   0.494859     0.010281
# 146  0.493279     0.013442
# 117  0.492623     0.014754
#
# [5 rows x 23 columns]

# %%
# Rows where gender rate difference is greater than .30 
diff_30 = recent_grads["gender_diff"] > .30

# %%
diff_30.head()
# Out:
# 0    True
# 1    True
# 2    True
# 3    True
# 4    True
# Name: gender_diff, dtype: bool

# %%
# Rows with more men
more_men = recent_grads.Men > recent_grads.Women

# %%
more_men
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#        ...
# 168    False
# 169    False
# 170    False
# 171    False
# 172    False
# Length: 173, dtype: bool

# %%
# Combine more_men and diff_30
more_men_and_diff_30 = np.logical_and(more_men,diff_30)

# %%
more_men_and_diff_30
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#        ...
# 168    False
# 169    False
# 170    False
# 171    False
# 172    False
# Length: 173, dtype: bool

# %%
# Find rows with more men and and gender rate difference greater than .30
fewer_women = recent_grads[more_men_and_diff_30]

# %%
fewer_women.head()
# Out:
#    Rank  Major_code                                      Major    Total  \
# 0     1        2419                      PETROLEUM ENGINEERING   2339.0
# 1     2        2416             MINING AND MINERAL ENGINEERING    756.0
# 2     3        2415                  METALLURGICAL ENGINEERING    856.0
# 3     4        2417  NAVAL ARCHITECTURE AND MARINE ENGINEERING   1258.0
# 4     5        2405                       CHEMICAL ENGINEERING  32260.0
#
#        Men    Women Major_category  ShareWomen  Sample_size  Employed  ...  \
# 0   2057.0    282.0    Engineering    0.120564           36      1976  ...
# 1    679.0     77.0    Engineering    0.101852            7       640  ...
# 2    725.0    131.0    Engineering    0.153037            3       648  ...
# 3   1123.0    135.0    Engineering    0.107313           16       758  ...
# 4  21239.0  11021.0    Engineering    0.341631          289     25694  ...
#
#    Unemployed  Unemployment_rate    Median    P25th     P75th  College_jobs  \
# 0          37           0.018381  110000.0  95000.0  125000.0          1534
# 1          85           0.117241   75000.0  55000.0   90000.0           350
# 2          16           0.024096   73000.0  50000.0  105000.0           456
# 3          40           0.050125   70000.0  43000.0   80000.0           529
# 4        1672           0.061098   65000.0  50000.0   75000.0         18314
#
#    Non_college_jobs  Low_wage_jobs  sharemen  gender_diff
# 0               364            193  0.879436     0.758871
# 1               257             50  0.898148     0.796296
# 2               176              0  0.846963     0.693925
# 3               102              0  0.892687     0.785374
# 4              4440            972  0.658369     0.316739
#
# [5 rows x 23 columns]

# %%
# Group by major category and count
recent_grads.groupby(['Major_category']).Major_category.count()
# Out:
# Major_category
# Agriculture & Natural Resources        10
# Arts                                    8
# Biology & Life Science                 14
# Business                               13
# Communications & Journalism             4
# Computers & Mathematics                11
# Education                              16
# Engineering                            29
# Health                                 12
# Humanities & Liberal Arts              15
# Industrial Arts & Consumer Services     7
# Interdisciplinary                       1
# Law & Public Policy                     5
# Physical Sciences                      10
# Psychology & Social Work                9
# Social Science                          9
# Name: Major_category, dtype: int64

# %%
fewer_women.groupby(['Major_category']).Major_category.count()
# Out:
# Major_category
# Agriculture & Natural Resources         5
# Business                                3
# Computers & Mathematics                 7
# Engineering                            26
# Industrial Arts & Consumer Services     4
# Law & Public Policy                     1
# Physical Sciences                       2
# Name: Major_category, dtype: int64

# %%
recent_grads.groupby(['Major_category']).gender_diff.mean()
# Out:
# Major_category
# Agriculture & Natural Resources        0.403082
# Arts                                   0.290622
# Biology & Life Science                 0.174386
# Business                               0.227085
# Communications & Journalism            0.316768
# Computers & Mathematics                0.386083
# Education                              0.510869
# Engineering                            0.522223
# Health                                 0.590304
# Humanities & Liberal Arts              0.349195
# Industrial Arts & Consumer Services    0.585843
# Interdisciplinary                      0.541802
# Law & Public Policy                    0.217270
# Physical Sciences                      0.237020
# Psychology & Social Work               0.588794
# Social Science                         0.232504
# Name: gender_diff, dtype: float64

# %%
# Find average number of low wage jobs and unemployment rate of each major category
dept_stats = recent_grads.groupby(['Major_category'])[['Low_wage_jobs', 'Unemployment_rate']].mean()
print(dept_stats)
# Out:
#                                      Low_wage_jobs  Unemployment_rate
# Major_category
# Agriculture & Natural Resources         789.900000           0.056328
# Arts                                   7514.500000           0.090173
# Biology & Life Science                 3053.000000           0.060918
# Business                               9752.923077           0.071064
# Communications & Journalism           12398.750000           0.075538
# Computers & Mathematics                1466.909091           0.084256
# Education                              2554.375000           0.051702
# Engineering                             864.793103           0.063334
# Health                                 2605.833333           0.065920
# Humanities & Liberal Arts              6282.666667           0.081008
# Industrial Arts & Consumer Services    3798.571429           0.048071
# Interdisciplinary                      1061.000000           0.070861
# Law & Public Policy                    4144.000000           0.090805
# Physical Sciences                      1407.800000           0.046511
# Psychology & Social Work               6249.555556           0.072065
# Social Science                         6020.000000           0.095729

# %% [markdown]
# ### Section 3: Visualizing Data

# %%
# Create scatter plot
plt.scatter(x=dept_stats["Unemployment_rate"],y=dept_stats["Low_wage_jobs"])

# Label x axis
plt.xlabel('Unemployment rate')

# Label y axis
plt.ylabel('Low pay jobs')

# Display the graph 
plt.show()

# %%
# Plot the red and triangle shaped scatter plot  
plt.scatter(x=dept_stats["Unemployment_rate"],y=dept_stats["Low_wage_jobs"],color="r",marker="^")

# Display the visualization
plt.show()

# %%
# Plot a histogram of sharewomen

plt.hist(recent_grads.ShareWomen)

# Show the plot
plt.show()

# %%
# Create scatter plot
dept_stats.plot(kind='scatter', x='Unemployment_rate', y='Low_wage_jobs')
plt.show()

# %%
# DataFrame of non-college job sums
df = recent_grads.groupby(['Major_category']).Non_college_jobs.sum()

# Plot bar chart
df.plot(kind="bar")

# Show graph
plt.show()

# %%
# DataFrame of college and non-college job sums
df1 = recent_grads.groupby(['Major_category'])[['College_jobs', 'Non_college_jobs']].sum()

# Plot bar chart
df1.plot(kind="bar")



# Show graph
plt.show()

# %%
# Print the size of the DataFrame
recent_grads.size
# Out:
# 3979

# %%
# Drop all rows with a missing value
recent_grads.dropna(axis=0,inplace=True)

# %%
# Print the size of the DataFrame
recent_grads.size
# Out:
# 3956

# %%
recent_grads.columns
# Out:
# Index(['Rank', 'Major_code', 'Major', 'Total', 'Men', 'Women',
#        'Major_category', 'ShareWomen', 'Sample_size', 'Employed', 'Full_time',
#        'Part_time', 'Full_time_year_round', 'Unemployed', 'Unemployment_rate',
#        'Median', 'P25th', 'P75th', 'College_jobs', 'Non_college_jobs',
#        'Low_wage_jobs', 'sharemen', 'gender_diff'],
#       dtype='object')

# %%
# Convert to numeric and divide by 1000
recent_grads['median'] = pd.to_numeric(recent_grads['Median'])/1000
recent_grads['p25th'] = pd.to_numeric(recent_grads['P25th'])/1000
recent_grads['p75th'] = pd.to_numeric(recent_grads['P75th'])/1000

# %%
# Select averages by major category
columns = ['median', 'p25th', 'p75th']
sal_quantiles = recent_grads.groupby(['Major_category'])[['median', 'p25th', 'p75th']].mean()

# %%
sal_quantiles
# Out:
#                                         median      p25th      p75th
# Major_category
# Agriculture & Natural Resources      35.111111  24.666667  45.566667
# Arts                                 33.062500  21.962500  43.662500
# Biology & Life Science               36.421429  26.614286  46.085714
# Business                             43.538462  33.461538  54.846154
# Communications & Journalism          34.500000  26.250000  44.975000
# Computers & Mathematics              42.745455  29.290909  58.090909
# Education                            32.350000  26.590625  38.562500
# Engineering                          57.382759  41.555172  70.448276
# Health                               36.825000  26.166667  50.250000
# Humanities & Liberal Arts            31.913333  23.493333  42.073333
# Industrial Arts & Consumer Services  36.342857  26.771429  45.142857
# Interdisciplinary                    35.000000  25.000000  44.000000
# Law & Public Policy                  42.200000  32.640000  55.000000
# Physical Sciences                    41.890000  28.350000  57.290000
# Psychology & Social Work             30.100000  25.333333  38.777778
# Social Science                       37.344444  28.355556  50.111111

# %%
# Plot the data
sal_quantiles.plot()

# Set xticks
plt.xticks(
    np.arange(len(sal_quantiles.index)),
    sal_quantiles.index, 
    rotation='vertical')

# Show the plot
plt.show()

# %%
# Plot with subplots
sal_quantiles.plot(subplots=True, figsize=(15,5))
plt.xticks(rotation=45)
plt.show()

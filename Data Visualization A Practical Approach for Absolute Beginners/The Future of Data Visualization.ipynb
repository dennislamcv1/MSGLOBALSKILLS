# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %% [markdown]
# ### Exercise 1: Familiarize Yourself with the New Dataset

# %%
df = pd.read_csv("ButterflyChartLab_Dataset.csv")

# %%
df
# Out:
#        FiscalYear     CurrencyName SalesTerritoryGroup SalesTerritoryCountry  \
# 0            2006  Canadian Dollar       North America                Canada
# 1            2006  Canadian Dollar       North America                Canada
# 2            2006  Canadian Dollar       North America                Canada
# 3            2006  Canadian Dollar       North America                Canada
# 4            2006  Canadian Dollar       North America                Canada
# ...           ...              ...                 ...                   ...
# 23755        2008        US Dollar       North America         United States
# 23756        2008        US Dollar       North America         United States
# 23757        2008        US Dollar       North America         United States
# 23758        2008        US Dollar       North America         United States
# 23759        2008        US Dollar       North America         United States
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23760 entries, 0 to 23759
# Data columns (total 11 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   FiscalYear             23760 non-null  int64
#  1   CurrencyName           23760 non-null  object
#  2   SalesTerritoryGroup    23760 non-null  object
#  3   SalesTerritoryCountry  23760 non-null  object
#  4   SalesTerritoryRegion   23760 non-null  object
#  5   ResellerName           23760 non-null  object
#  6   ProductLine            22850 non-null  object
#  7   Color                  21455 non-null  object
#  8   ListPrice              23760 non-null  float64
#  9   EnglishProductName     23760 non-null  object
#  10  SalesTotal             23760 non-null  float64
# dtypes: float64(2), int64(1), object(8)
# memory usage: 2.0+ MB

# %%
df["EnglishProductName"].str.contains("Frame").sum()
# Out:
# 4912

# %%
df1 = df[df["EnglishProductName"].str.contains("Frame")]

# %%
df1
# Out:
#        FiscalYear     CurrencyName SalesTerritoryGroup SalesTerritoryCountry  \
# 5            2006  Canadian Dollar       North America                Canada
# 6            2006  Canadian Dollar       North America                Canada
# 7            2006  Canadian Dollar       North America                Canada
# 8            2006  Canadian Dollar       North America                Canada
# 9            2006  Canadian Dollar       North America                Canada
# ...           ...              ...                 ...                   ...
# 23728        2008        US Dollar       North America         United States
# 23729        2008        US Dollar       North America         United States
# 23730        2008        US Dollar       North America         United States
# 23731        2008        US Dollar       North America         United States
# 23732        2008        US Dollar       North America         United States
#
# ...

# %%
df1.reset_index(inplace=True, drop=True)

# %%
df1
# Out:
#       FiscalYear     CurrencyName SalesTerritoryGroup SalesTerritoryCountry  \
# 0           2006  Canadian Dollar       North America                Canada
# 1           2006  Canadian Dollar       North America                Canada
# 2           2006  Canadian Dollar       North America                Canada
# 3           2006  Canadian Dollar       North America                Canada
# 4           2006  Canadian Dollar       North America                Canada
# ...          ...              ...                 ...                   ...
# 4907        2008        US Dollar       North America         United States
# 4908        2008        US Dollar       North America         United States
# 4909        2008        US Dollar       North America         United States
# 4910        2008        US Dollar       North America         United States
# 4911        2008        US Dollar       North America         United States
#
# ...

# %% [markdown]
# ### Exercise 2: Create a PivotTable

# %%
df2 = pd.pivot_table(data=df1, index=["EnglishProductName"], columns="SalesTerritoryRegion", values=["SalesTotal"], aggfunc='sum')

# %%
df2
# Out:
#                                SalesTotal                           \
# SalesTerritoryRegion            Australia       Canada     Central
# EnglishProductName
# HL Mountain Frame - Black, 38    2429.280   97886.6210  40261.4392
# HL Mountain Frame - Black, 42    7287.840  168943.2413  92724.3111
# HL Mountain Frame - Black, 44         NaN    3239.0400   1619.5200
# HL Mountain Frame - Black, 48         NaN   21863.5200  15385.4400
# HL Mountain Frame - Silver, 38   5730.900  172908.0038  79820.7203
# ...                                   ...          ...         ...
# ML Road Frame - Red, 52               NaN   11063.8380   1070.6940
# ML Road Frame-W - Yellow, 38          NaN   73034.3058  30887.8983
# ML Road Frame-W - Yellow, 40          NaN   14340.8097   4347.6663
# ML Road Frame-W - Yellow, 44      356.898  109854.5244  37344.5070
# ML Road Frame-W - Yellow, 48          NaN   67551.0549  26767.3491
#
#                                                                    \
# ...

# %%
df2.columns
# Out:
# MultiIndex([('SalesTotal',      'Australia'),
#             ('SalesTotal',         'Canada'),
#             ('SalesTotal',        'Central'),
#             ('SalesTotal',         'France'),
#             ('SalesTotal',        'Germany'),
#             ('SalesTotal',      'Northeast'),
#             ('SalesTotal',      'Northwest'),
#             ('SalesTotal',      'Southeast'),
#             ('SalesTotal',      'Southwest'),
#             ('SalesTotal', 'United Kingdom')],
#            names=[None, 'SalesTerritoryRegion'])

# %%
df2.columns = df2.columns.get_level_values(1)

# %%
df2.columns
# Out:
# Index(['Australia', 'Canada', 'Central', 'France', 'Germany', 'Northeast',
#        'Northwest', 'Southeast', 'Southwest', 'United Kingdom'],
#       dtype='object', name='SalesTerritoryRegion')

# %%
df2
# Out:
# SalesTerritoryRegion            Australia       Canada     Central  \
# EnglishProductName
# HL Mountain Frame - Black, 38    2429.280   97886.6210  40261.4392
# HL Mountain Frame - Black, 42    7287.840  168943.2413  92724.3111
# HL Mountain Frame - Black, 44         NaN    3239.0400   1619.5200
# HL Mountain Frame - Black, 48         NaN   21863.5200  15385.4400
# HL Mountain Frame - Silver, 38   5730.900  172908.0038  79820.7203
# ...                                   ...          ...         ...
# ML Road Frame - Red, 52               NaN   11063.8380   1070.6940
# ML Road Frame-W - Yellow, 38          NaN   73034.3058  30887.8983
# ML Road Frame-W - Yellow, 40          NaN   14340.8097   4347.6663
# ML Road Frame-W - Yellow, 44      356.898  109854.5244  37344.5070
# ML Road Frame-W - Yellow, 48          NaN   67551.0549  26767.3491
#
# SalesTerritoryRegion                France    Germany   Northeast  \
# EnglishProductName
# ...

# %% [markdown]
# ### Exercise 3: Add a Heatmap to Your Pivot Table

# %%
plt.figure(figsize=(15,25))
sns.heatmap(data=df2, cmap="coolwarm", annot=True, fmt='.9g')
plt.show()

# %% [markdown]
# ### Exercise 4: Turn Your Pivot-Heatmap into a Butterfly Combo Chart

# %%
sns.jointplot(x=df2.Canada, y=df2.Australia, data=df2)
plt.show()
